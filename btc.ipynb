# %%
import pandas as pd

# %%
df = pd.read_csv("data/BTCUSD_day.csv")

# %%
df
# Out:
#             Date    BTCUSD
# 0     2015-10-08    242.50
# 1     2015-10-09    243.95
# 2     2015-10-10    245.39
# 3     2015-10-11    246.30
# 4     2015-10-12    249.50
# 5     2015-10-13    247.60
# 6     2015-10-14    250.00
# 7     2015-10-15    253.00
# 8     2015-10-16    255.90
# 9     2015-10-17    263.75
# 10    2015-10-18    272.47
# 11    2015-10-19    268.46
# 12    2015-10-20    272.49
# 13    2015-10-21    272.10
# 14    2015-10-22    271.64
# 15    2015-10-23    276.89
# 16    2015-10-24    280.20
# 17    2015-10-25    285.00
# 18    2015-10-26    289.38
# 19    2015-10-27    288.54
# 20    2015-10-28    298.20
# 21    2015-10-29    307.05
# 22    2015-10-30    314.89
# 23    2015-10-31    330.36
# 24    2015-11-01    315.00
# 25    2015-11-02    330.00
# 26    2015-11-03    367.85
# 27    2015-11-04    400.00
# 28    2015-11-05    410.00
# 29    2015-11-06    379.42
# 30    2015-11-07    376.00
# 31    2015-11-08    388.13
# 32    2015-11-09    377.00
# ...

# %%
pd.set_option("display.max_rows", 1647)
